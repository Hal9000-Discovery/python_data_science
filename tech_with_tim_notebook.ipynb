# %%
import pandas as pd

df = pd.read_csv("data/projections_20202021.csv")

# %%
# Display the first five rows of the DataFrame
df.head()
# Out:
#    player_id              name position  goals  assists  points  shots  \
# 0    8478402    Connor McDavid        C     26       48      74    173
# 1    8477934    Leon Draisaitl        C     29       43      72    160
# 2    8476453   Nikita Kucherov       RW     24       41      65    158
# 3    8477492  Nathan MacKinnon        C     25       39      64    233
# 4    8478550    Artemi Panarin       LW     21       42      63    150
#
#    timeOnIcePerGame
# 0             20.78
# 1             21.35
# 2             18.11
# 3             20.22
# 4             19.47

# %%
# Display the last five rows of the DataFrame
df.tail()
# Out:
#      player_id               name position  goals  assists  points  shots  \
# 505    8475625         Matt Irwin        D      0        6       6     77
# 506    8474134      Yannick Weber        D      1        4       5     60
# 507    8474568        Luke Schenn        D      1        4       5     62
# 508    8474230      Micheal Haley        C      2        2       4     33
# 509    8470318  Jonathan Ericsson        D      0        2       2     48
#
#      timeOnIcePerGame
# 505             13.71
# 506             13.40
# 507             12.35
# 508              6.23
# 509             14.12

# %%
# Display summary statistics for numerical columns

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   player_id         510 non-null    int64
#  1   name              510 non-null    object
#  2   position          510 non-null    object
#  3   goals             510 non-null    int64
#  4   assists           510 non-null    int64
#  5   points            510 non-null    int64
#  6   shots             510 non-null    int64
#  7   timeOnIcePerGame  510 non-null    float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 32.0+ KB

# %%
# Display summary statistics for numerical columns
df.describe()
# Out:
#           player_id       goals     assists      points      shots  \
# count  5.100000e+02  510.000000  510.000000  510.000000  510.00000
# mean   8.475622e+06    8.925490   15.249020   24.174510   97.67451
# std    2.536202e+03    6.179879    7.825877   12.773181   34.83111
# min    8.465009e+06    0.000000    2.000000    2.000000   33.00000
# 25%    8.474235e+06    4.000000    9.000000   14.000000   70.00000
# 50%    8.476290e+06    8.000000   13.000000   21.000000   91.00000
# 75%    8.477455e+06   13.000000   20.000000   31.000000  121.00000
# max    8.480172e+06   33.000000   48.000000   74.000000  233.00000
#
#        timeOnIcePerGame
# count        510.000000
# mean          16.303059
# std            3.307740
# min            6.230000
# 25%           13.850000
# 50%           16.380000
# 75%           18.527500
# max           24.310000

# %%
df.columns
# Out:
# Index(['player_id', 'name', 'position', 'goals', 'assists', 'points', 'shots',
#        'timeOnIcePerGame'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=510, step=1)

# %%
# Retunning a specific column
# Return a series representing the "name" column
# NOT A PANDA BUT A SERIES. NOT A DATAFRAME
df["name"]
# Out:
# 0         Connor McDavid
# 1         Leon Draisaitl
# 2        Nikita Kucherov
# 3       Nathan MacKinnon
# 4         Artemi Panarin
#              ...
# 505           Matt Irwin
# 506        Yannick Weber
# 507          Luke Schenn
# 508        Micheal Haley
# 509    Jonathan Ericsson
# Name: name, Length: 510, dtype: object

# %%
# return the length of the "name" column
len(df["name"])
# Out:
# 510

# %%
# return the set of unique values in the "name" column

set(df["name"])
# Out:
# {'Aaron Ekblad',
#  'Adam Erne',
#  'Adam Henrique',
#  'Adam Larsson',
#  'Adam Lowry',
#  'Adam Pelech',
#  'Adrian Kempe',
#  'Alec Martinez',
#  'Aleksander Barkov',
#  'Alex Biega',
#  'Alex Chiasson',
#  'Alex DeBrincat',
#  'Alex Galchenyuk',
#  'Alex Goligoski',
#  'Alex Iafallo',
#  'Alex Killorn',
#  'Alex Ovechkin',
#  'Alex Pietrangelo',
#  'Alex Tuch',
#  'Alexander Edler',
#  'Alexander Kerfoot',
#  'Alexander Radulov',
#  'Alexander Steen',
#  'Alexander Wennberg',
#  'Anders Bjork',
#  'Anders Lee',
#  'Andre Burakovsky',
#  'Andreas Athanasiou',
#  'Andrej Sekera',
#  'Andrew Cogliano',
#  'Andrew Copp',
#  'Andrew Shaw',
#  'Andy Greene',
#  'Anthony Beauvillier',
#  'Anthony Bitetto',
#  'Anthony Cirelli',
#  'Anthony Duclair',
#  'Anthony Mantha',
#  'Antoine Roussel',
#  'Anton Stralman',
#  'Anze Kopitar',
#  'Artem Anisimov',
#  'Artemi Panarin',
#  'Artturi Lehkonen',
#  'Austin Watson',
#  'Auston Matthews',
#  'Barclay Goodrow',
#  'Ben Chiarot',
# ...

# %%
# Return a DataFrame with only the "name" and "position" columns
# Can put a list of columns you want to return
# index by column
df[["name", "position"]]
# Out:
#                   name position
# 0       Connor McDavid        C
# 1       Leon Draisaitl        C
# 2      Nikita Kucherov       RW
# 3     Nathan MacKinnon        C
# 4       Artemi Panarin       LW
# ..                 ...      ...
# 505         Matt Irwin        D
# 506      Yannick Weber        D
# 507        Luke Schenn        D
# 508      Micheal Haley        C
# 509  Jonathan Ericsson        D
#
# [510 rows x 2 columns]

# %%
# index by rows
# Return the first row of the DataFrame
df.iloc[0]
# Out:
# player_id                  8478402
# name                Connor McDavid
# position                         C
# goals                           26
# assists                         48
# points                          74
# shots                          173
# timeOnIcePerGame             20.78
# Name: 0, dtype: object

# %%
# Return the 11th row of the DataFrame (index 10)
df.iloc[10]
# Out:
# player_id                8474141
# name                Patrick Kane
# position                      RW
# goals                         23
# assists                       36
# points                        59
# shots                        200
# timeOnIcePerGame           20.32
# Name: 10, dtype: object

# %%
list(df.iloc[10])
# Out:
# [np.int64(8474141),
#  'Patrick Kane',
#  'RW',
#  np.int64(23),
#  np.int64(36),
#  np.int64(59),
#  np.int64(200),
#  np.float64(20.32)]

# %%
#df.iloc[10][0]
#df.iloc[10][1]
df.iloc[10]["name"]
# Out:
# 'Patrick Kane'

# %%
df.head()
# Out:
#    player_id              name position  goals  assists  points  shots  \
# 0    8478402    Connor McDavid        C     26       48      74    173
# 1    8477934    Leon Draisaitl        C     29       43      72    160
# 2    8476453   Nikita Kucherov       RW     24       41      65    158
# 3    8477492  Nathan MacKinnon        C     25       39      64    233
# 4    8478550    Artemi Panarin       LW     21       42      63    150
#
#    timeOnIcePerGame
# 0             20.78
# 1             21.35
# 2             18.11
# 3             20.22
# 4             19.47

# %%
# Return a DataFrame with only the rows where the "position" column is "LW" and the "goals" column is greater than 20
df[df["position"] == "LW"]
# Out:
#      player_id                name position  goals  assists  points  shots  \
# 4      8478550      Artemi Panarin       LW     21       42      63    150
# 11     8473419       Brad Marchand       LW     20       39      59    139
# 15     8476456  Jonathan Huberdeau       LW     18       37      55    127
# 22     8471214       Alex Ovechkin       LW     31       18      49    217
# 24     8478398         Kyle Connor       LW     25       24      49    172
# ..         ...                 ...      ...    ...      ...     ...    ...
# 458    8476948       Charles Hudon       LW      5        6      11     83
# 470    8474709         Matt Martin       LW      5        5      10     53
# 488    8471716   Justin Abdelkader       LW      2        6       8     55
# 496    8476207       Brian Gibbons       LW      3        4       7     42
# 501    8475268     Gabriel Bourque       LW      2        5       7     41
#
#      timeOnIcePerGame
# 4               19.47
# ...

# %%
# Return a DataFrame with only the rows where the "position" column is "LW" and the "goals" column is greater than 20
df[(df["position"] == "LW") & (df["goals"] > 20)]
# Out:
#     player_id            name position  goals  assists  points  shots  \
# 4     8478550  Artemi Panarin       LW     21       42      63    150
# 22    8471214   Alex Ovechkin       LW     31       18      49    217
# 24    8478398     Kyle Connor       LW     25       24      49    172
# 61    8475169    Evander Kane       LW     21       18      39    177
#
#     timeOnIcePerGame
# 4              19.47
# 22             19.62
# 24             19.80
# 61             18.47

# %%
df[(df["position"] == "LW") | (df["goals"] > 20)]
# Out:
#      player_id               name position  goals  assists  points  shots  \
# 0      8478402     Connor McDavid        C     26       48      74    173
# 1      8477934     Leon Draisaitl        C     29       43      72    160
# 2      8476453    Nikita Kucherov       RW     24       41      65    158
# 3      8477492   Nathan MacKinnon        C     25       39      64    233
# 4      8478550     Artemi Panarin       LW     21       42      63    150
# ..         ...                ...      ...    ...      ...     ...    ...
# 458    8476948      Charles Hudon       LW      5        6      11     83
# 470    8474709        Matt Martin       LW      5        5      10     53
# 488    8471716  Justin Abdelkader       LW      2        6       8     55
# 496    8476207      Brian Gibbons       LW      3        4       7     42
# 501    8475268    Gabriel Bourque       LW      2        5       7     41
#
#      timeOnIcePerGame
# 0               20.78
# 1               21.35
# ...

# %%
df[df["name"].str.startswith("K") ]
# Out:
#      player_id               name position  goals  assists  points  shots  \
# 24     8478398        Kyle Connor       LW     25       24      49    172
# 90     8475151      Kyle Palmieri       RW     19       17      36    133
# 91     8477942        Kevin Fiala       LW     15       21      36    134
# 98     8471724        Kris Letang        D     10       25      35    148
# 102    8475763        Kevin Hayes        C     16       19      35    128
# 140    8478099       Kevin Labanc       RW     11       19      30    123
# 146    8471735       Keith Yandle        D      3       27      30    100
# 171    8477953    Kasperi Kapanen       RW     12       16      28    105
# 222    8474068        Kyle Turris        C      7       17      24     80
# 270    8474031  Kevin Shattenkirk        D      3       17      20     97
# 298    8473449        Kyle Okposo       RW      8       11      19     89
# 352    8475160      Kyle Clifford       LW      7        9      16     87
# ...

# %%
len(df[df["name"].str.startswith("K") ])
# Out:
# 14

# %%
df[df["name"].str.endswith("s")]
# Out:
#      player_id                 name position  goals  assists  points  shots  \
# 9      8479318      Auston Matthews        C     33       26      59    214
# 14     8474564       Steven Stamkos        C     24       32      56    155
# 28     8475166         John Tavares        C     22       26      48    166
# 33     8476454  Ryan Nugent-Hopkins        C     18       28      46    140
# 41     8473604       Jonathan Toews        C     15       28      43    133
# 70     8477940       Nikolaj Ehlers       LW     18       21      39    148
# 79     8470613          Brent Burns        D      8       29      37    163
# 82     8479400    Pierre-Luc Dubois        C     15       22      37    123
# 102    8475763          Kevin Hayes        C     16       19      35    128
# 104    8475176           Ryan Ellis        D      7       27      34    112
# 154    8477495           Seth Jones        D      6       23      29    121
# ...

# %%
df[df["position"].isin(["LW", "RW"])]
# Out:
#      player_id               name position  goals  assists  points  shots  \
# 2      8476453    Nikita Kucherov       RW     24       41      65    158
# 4      8478550     Artemi Panarin       LW     21       42      63    150
# 5      8477956     David Pastrnak       RW     30       32      62    201
# 10     8474141       Patrick Kane       RW     23       36      59    200
# 11     8473419      Brad Marchand       LW     20       39      59    139
# ..         ...                ...      ...    ...      ...     ...    ...
# 471    8471426       Troy Brouwer       RW      6        4      10     53
# 477    8477401        John Hayden       RW      5        4       9     55
# 488    8471716  Justin Abdelkader       LW      2        6       8     55
# 496    8476207      Brian Gibbons       LW      3        4       7     42
# 501    8475268    Gabriel Bourque       LW      2        5       7     41
#
#      timeOnIcePerGame
# 2               18.11
# 4               19.47
# ...

# %%
df[~df["position"].isin(["LW", "RW"])]
# Out:
#      player_id               name position  goals  assists  points  shots  \
# 0      8478402     Connor McDavid        C     26       48      74    173
# 1      8477934     Leon Draisaitl        C     29       43      72    160
# 3      8477492   Nathan MacKinnon        C     25       39      64    233
# 6      8471215      Evgeni Malkin        C     20       40      60    153
# 7      8476459     Mika Zibanejad        C     30       29      59    180
# ..         ...                ...      ...    ...      ...     ...    ...
# 505    8475625         Matt Irwin        D      0        6       6     77
# 506    8474134      Yannick Weber        D      1        4       5     60
# 507    8474568        Luke Schenn        D      1        4       5     62
# 508    8474230      Micheal Haley        C      2        2       4     33
# 509    8470318  Jonathan Ericsson        D      0        2       2     48
#
#      timeOnIcePerGame
# 0               20.78
# 1               21.35
# ...

# %%
# Locate then entry I want
df.loc[df["name"] == "Patrick Kane"]
# Out:
#     player_id          name position  goals  assists  points  shots  \
# 10    8474141  Patrick Kane       RW     23       36      59    200
#
#     timeOnIcePerGame
# 10             20.32

# %%
# Look up a value and change it
df.loc[df["name"] == "Patrick Kane","position"]
# Out:
# 10    RW
# Name: position, dtype: object

# %%
# Change the position of Patrick Kane to "bench"
df.loc[df["name"] == "Patrick Kane", "position"] = "bench"

# %%
#  display the row for Patrick Kane to verify the change
df.loc[df["name"] == "Patrick Kane"]
# Out:
#     player_id          name position  goals  assists  points  shots  \
# 10    8474141  Patrick Kane    bench     23       36      59    200
#
#     timeOnIcePerGame
# 10             20.32

# %%
df["name"] = df["name"].str.upper()

# %%
df["name"]
# Out:
# 0         CONNOR MCDAVID
# 1         LEON DRAISAITL
# 2        NIKITA KUCHEROV
# 3       NATHAN MACKINNON
# 4         ARTEMI PANARIN
#              ...
# 505           MATT IRWIN
# 506        YANNICK WEBER
# 507          LUKE SCHENN
# 508        MICHEAL HALEY
# 509    JONATHAN ERICSSON
# Name: name, Length: 510, dtype: object

# %%
df.loc[df["name"] == "MICHEAL HALEY"]
# Out:
#      player_id           name position  goals  assists  points  shots  \
# 508    8474230  MICHEAL HALEY        C      2        2       4     33
#
#      timeOnIcePerGame
# 508              6.23

# %%
df = df.drop(508)

# %%
df.tail()
# Out:
#      player_id               name position  goals  assists  points  shots  \
# 504    8474090      BRENDAN SMITH        D      1        5       6     44
# 505    8475625         MATT IRWIN        D      0        6       6     77
# 506    8474134      YANNICK WEBER        D      1        4       5     60
# 507    8474568        LUKE SCHENN        D      1        4       5     62
# 509    8470318  JONATHAN ERICSSON        D      0        2       2     48
#
#      timeOnIcePerGame
# 504             11.41
# 505             13.71
# 506             13.40
# 507             12.35
# 509             14.12

# %%
# display the number of rows and columns in the DataFrame
df.dropna()  # Returns a new DataFrame with rows containing any NaN values removed
df.fillna({"position": "unknown"}, inplace=True) # Modifies the existing

df
# Out:
#      player_id               name position  goals  assists  points  shots  \
# 0      8478402     CONNOR MCDAVID        C     26       48      74    173
# 1      8477934     LEON DRAISAITL        C     29       43      72    160
# 2      8476453    NIKITA KUCHEROV       RW     24       41      65    158
# 3      8477492   NATHAN MACKINNON        C     25       39      64    233
# 4      8478550     ARTEMI PANARIN       LW     21       42      63    150
# ..         ...                ...      ...    ...      ...     ...    ...
# 504    8474090      BRENDAN SMITH        D      1        5       6     44
# 505    8475625         MATT IRWIN        D      0        6       6     77
# 506    8474134      YANNICK WEBER        D      1        4       5     60
# 507    8474568        LUKE SCHENN        D      1        4       5     62
# 509    8470318  JONATHAN ERICSSON        D      0        2       2     48
#
#      timeOnIcePerGame
# 0               20.78
# 1               21.35
# ...

# %%
df.rename(columns={"goals": "G", "assists": "A"}, inplace=True)

df
# Out:
#      player_id               name position   G   A  points  shots  \
# 0      8478402     CONNOR MCDAVID        C  26  48      74    173
# 1      8477934     LEON DRAISAITL        C  29  43      72    160
# 2      8476453    NIKITA KUCHEROV       RW  24  41      65    158
# 3      8477492   NATHAN MACKINNON        C  25  39      64    233
# 4      8478550     ARTEMI PANARIN       LW  21  42      63    150
# ..         ...                ...      ...  ..  ..     ...    ...
# 504    8474090      BRENDAN SMITH        D   1   5       6     44
# 505    8475625         MATT IRWIN        D   0   6       6     77
# 506    8474134      YANNICK WEBER        D   1   4       5     60
# 507    8474568        LUKE SCHENN        D   1   4       5     62
# 509    8470318  JONATHAN ERICSSON        D   0   2       2     48
#
#      timeOnIcePerGame
# 0               20.78
# 1               21.35
# 2               18.11
# 3               20.22
# 4               19.47
# ..                ...
# ...

# %%
df["G"].value_counts()
# Out:
# G
# 3     43
# 6     40
# 7     40
# 9     39
# 5     34
# 2     31
# 4     28
# 1     28
# 8     26
# 12    21
# 16    20
# 15    19
# 14    19
# 10    18
# 11    16
# 13    15
# 17    13
# 19    12
# 18    10
# 0      9
# 21     5
# 20     5
# 24     4
# 25     3
# 22     3
# 23     2
# 30     2
# 31     1
# 33     1
# 29     1
# 26     1
# Name: count, dtype: int64

# %%
df.groupby("position")["G"].sum()
# Out:
# position
# C        1856
# D         643
# LW       1121
# RW        907
# bench      23
# Name: G, dtype: int64

# %%
df.sort_values("name", ascending=True)
# Out:
#      player_id               name position   G   A  points  shots  \
# 169    8477932       AARON EKBLAD        D   6  22      28    116
# 432    8477454          ADAM ERNE       LW   5   7      12     67
# 159    8474641      ADAM HENRIQUE        C  15  14      29    113
# 472    8476457       ADAM LARSSON        D   2   8      10     71
# 350    8476392         ADAM LOWRY        C   7   9      16     79
# ..         ...                ...      ...  ..  ..     ...    ...
# 148    8478460      ZACH WERENSKI        D  12  18      30    141
# 198    8475178       ZACK KASSIAN       RW  12  14      26     90
# 373    8474250         ZACK SMITH       LW   5   9      14     58
# 457    8465009        ZDENO CHARA        D   3   8      11     70
# 356    8476878  ZEMGUS GIRGENSONS        C   8   8      16     71
#
#      timeOnIcePerGame
# 169             21.75
# 432             11.51
# 159             16.14
# 472             19.03
# 350             14.43
# ..                ...
# ...

# %%
df.to_csv("data/modified_projections_20202021.csv", index=False)
