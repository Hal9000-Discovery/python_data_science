# %%
import pandas as pd

df = pd.read_csv("data/projections_20202021.csv")

# %%
df
# Out:
#      player_id               name position  goals  assists  points  shots  \
# 0      8478402     Connor McDavid        C     26       48      74    173
# 1      8477934     Leon Draisaitl        C     29       43      72    160
# 2      8476453    Nikita Kucherov       RW     24       41      65    158
# 3      8477492   Nathan MacKinnon        C     25       39      64    233
# 4      8478550     Artemi Panarin       LW     21       42      63    150
# ..         ...                ...      ...    ...      ...     ...    ...
# 505    8475625         Matt Irwin        D      0        6       6     77
# 506    8474134      Yannick Weber        D      1        4       5     60
# 507    8474568        Luke Schenn        D      1        4       5     62
# 508    8474230      Micheal Haley        C      2        2       4     33
# 509    8470318  Jonathan Ericsson        D      0        2       2     48
#
#      timeOnIcePerGame
# 0               20.78
# 1               21.35
# ...

# %%
df.shape
# Out:
# (510, 8)

# %%
rows, columns = df.shape
print(f"Rows: {rows}, Columns: {columns}")
# Out:
# Rows: 510, Columns: 8

# %%
df[2:5]
# Out:
#    player_id              name position  goals  assists  points  shots  \
# 2    8476453   Nikita Kucherov       RW     24       41      65    158
# 3    8477492  Nathan MacKinnon        C     25       39      64    233
# 4    8478550    Artemi Panarin       LW     21       42      63    150
#
#    timeOnIcePerGame
# 2             18.11
# 3             20.22
# 4             19.47

# %%
df[:]
# Out:
#      player_id               name position  goals  assists  points  shots  \
# 0      8478402     Connor McDavid        C     26       48      74    173
# 1      8477934     Leon Draisaitl        C     29       43      72    160
# 2      8476453    Nikita Kucherov       RW     24       41      65    158
# 3      8477492   Nathan MacKinnon        C     25       39      64    233
# 4      8478550     Artemi Panarin       LW     21       42      63    150
# ..         ...                ...      ...    ...      ...     ...    ...
# 505    8475625         Matt Irwin        D      0        6       6     77
# 506    8474134      Yannick Weber        D      1        4       5     60
# 507    8474568        Luke Schenn        D      1        4       5     62
# 508    8474230      Micheal Haley        C      2        2       4     33
# 509    8470318  Jonathan Ericsson        D      0        2       2     48
#
#      timeOnIcePerGame
# 0               20.78
# 1               21.35
# ...

# %%
df.columns
# Out:
# Index(['player_id', 'name', 'position', 'goals', 'assists', 'points', 'shots',
#        'timeOnIcePerGame'],
#       dtype='object')

# %%
df.name
# Out:
# 0         Connor McDavid
# 1         Leon Draisaitl
# 2        Nikita Kucherov
# 3       Nathan MacKinnon
# 4         Artemi Panarin
#              ...
# 505           Matt Irwin
# 506        Yannick Weber
# 507          Luke Schenn
# 508        Micheal Haley
# 509    Jonathan Ericsson
# Name: name, Length: 510, dtype: object

# %%
df['name']
# Out:
# 0         Connor McDavid
# 1         Leon Draisaitl
# 2        Nikita Kucherov
# 3       Nathan MacKinnon
# 4         Artemi Panarin
#              ...
# 505           Matt Irwin
# 506        Yannick Weber
# 507          Luke Schenn
# 508        Micheal Haley
# 509    Jonathan Ericsson
# Name: name, Length: 510, dtype: object

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
df.columns
# Out:
# Index(['player_id', 'name', 'position', 'goals', 'assists', 'points', 'shots',
#        'timeOnIcePerGame'],
#       dtype='object')

# %%
df[['name', 'position','goals','shots']]
# Out:
#                   name position  goals  shots
# 0       Connor McDavid        C     26    173
# 1       Leon Draisaitl        C     29    160
# 2      Nikita Kucherov       RW     24    158
# 3     Nathan MacKinnon        C     25    233
# 4       Artemi Panarin       LW     21    150
# ..                 ...      ...    ...    ...
# 505         Matt Irwin        D      0     77
# 506      Yannick Weber        D      1     60
# 507        Luke Schenn        D      1     62
# 508      Micheal Haley        C      2     33
# 509  Jonathan Ericsson        D      0     48
#
# [510 rows x 4 columns]

# %%
df[['goals','shots']].max()
# Out:
# goals     33
# shots    233
# dtype: int64

# %%
df[['goals','shots']].min()
# Out:
# goals     0
# shots    33
# dtype: int64

# %%
df[['goals','shots']].mean()
# Out:
# goals     8.92549
# shots    97.67451
# dtype: float64

# %%
df[['goals','shots']].std()
# Out:
# goals     6.179879
# shots    34.831110
# dtype: float64

# %%
df.describe()
# Out:
#           player_id       goals     assists      points      shots  \
# count  5.100000e+02  510.000000  510.000000  510.000000  510.00000
# mean   8.475622e+06    8.925490   15.249020   24.174510   97.67451
# std    2.536202e+03    6.179879    7.825877   12.773181   34.83111
# min    8.465009e+06    0.000000    2.000000    2.000000   33.00000
# 25%    8.474235e+06    4.000000    9.000000   14.000000   70.00000
# 50%    8.476290e+06    8.000000   13.000000   21.000000   91.00000
# 75%    8.477455e+06   13.000000   20.000000   31.000000  121.00000
# max    8.480172e+06   33.000000   48.000000   74.000000  233.00000
#
#        timeOnIcePerGame
# count        510.000000
# mean          16.303059
# std            3.307740
# min            6.230000
# 25%           13.850000
# 50%           16.380000
# 75%           18.527500
# max           24.310000

# %%
df[df.goals > 20]
# Out:
#     player_id              name position  goals  assists  points  shots  \
# 0     8478402    Connor McDavid        C     26       48      74    173
# 1     8477934    Leon Draisaitl        C     29       43      72    160
# 2     8476453   Nikita Kucherov       RW     24       41      65    158
# 3     8477492  Nathan MacKinnon        C     25       39      64    233
# 4     8478550    Artemi Panarin       LW     21       42      63    150
# 5     8477956    David Pastrnak       RW     30       32      62    201
# 7     8476459    Mika Zibanejad        C     30       29      59    180
# 9     8479318   Auston Matthews        C     33       26      59    214
# 10    8474141      Patrick Kane       RW     23       36      59    200
# 12    8478403       Jack Eichel        C     24       33      57    188
# 14    8474564    Steven Stamkos        C     24       32      56    155
# 16    8476460    Mark Scheifele        C     22       31      53    130
# ...

# %%
df[df.goals == df.goals.max()]
# Out:
#    player_id             name position  goals  assists  points  shots  \
# 9    8479318  Auston Matthews        C     33       26      59    214
#
#    timeOnIcePerGame
# 9             19.63

# %%
df[df.goals == df['goals'].max()]
# Out:
#    player_id             name position  goals  assists  points  shots  \
# 9    8479318  Auston Matthews        C     33       26      59    214
#
#    timeOnIcePerGame
# 9             19.63

# %%
df.loc[df.goals == df['goals'].max()]['name']
# Out:
# 9    Auston Matthews
# Name: name, dtype: object

# %%
df[df.goals == df['goals'].max()]['name']
# Out:
# 9    Auston Matthews
# Name: name, dtype: object

# %%
df[['name','goals']][df.goals == df['goals'].max()]
# Out:
#               name  goals
# 9  Auston Matthews     33

# %%
# To modify the original dataframe, use inplace=True

df.set_index('name', inplace=True)

# %%
df
# Out:
#                    player_id position  goals  assists  points  shots  \
# name
# Connor McDavid       8478402        C     26       48      74    173
# Leon Draisaitl       8477934        C     29       43      72    160
# Nikita Kucherov      8476453       RW     24       41      65    158
# Nathan MacKinnon     8477492        C     25       39      64    233
# Artemi Panarin       8478550       LW     21       42      63    150
# ...                      ...      ...    ...      ...     ...    ...
# Matt Irwin           8475625        D      0        6       6     77
# Yannick Weber        8474134        D      1        4       5     60
# Luke Schenn          8474568        D      1        4       5     62
# Micheal Haley        8474230        C      2        2       4     33
# Jonathan Ericsson    8470318        D      0        2       2     48
#
#                    timeOnIcePerGame
# name
# Connor McDavid                20.78
# Leon Draisaitl                21.35
# ...

# %%
df.loc['Matt Irwin']
# Out:
# player_id           8475625
# position                  D
# goals                     0
# assists                   6
# points                    6
# shots                    77
# timeOnIcePerGame      13.71
# Name: Matt Irwin, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                   name  player_id position  goals  assists  points  shots  \
# 0       Connor McDavid    8478402        C     26       48      74    173
# 1       Leon Draisaitl    8477934        C     29       43      72    160
# 2      Nikita Kucherov    8476453       RW     24       41      65    158
# 3     Nathan MacKinnon    8477492        C     25       39      64    233
# 4       Artemi Panarin    8478550       LW     21       42      63    150
# ..                 ...        ...      ...    ...      ...     ...    ...
# 505         Matt Irwin    8475625        D      0        6       6     77
# 506      Yannick Weber    8474134        D      1        4       5     60
# 507        Luke Schenn    8474568        D      1        4       5     62
# 508      Micheal Haley    8474230        C      2        2       4     33
# 509  Jonathan Ericsson    8470318        D      0        2       2     48
#
#      timeOnIcePerGame
# 0               20.78
# 1               21.35
# ...

# %%
df.set_index('position', inplace=True)
df
# Out:
#                        name  player_id  goals  assists  points  shots  \
# position
# C            Connor McDavid    8478402     26       48      74    173
# C            Leon Draisaitl    8477934     29       43      72    160
# RW          Nikita Kucherov    8476453     24       41      65    158
# C          Nathan MacKinnon    8477492     25       39      64    233
# LW           Artemi Panarin    8478550     21       42      63    150
# ...                     ...        ...    ...      ...     ...    ...
# D                Matt Irwin    8475625      0        6       6     77
# D             Yannick Weber    8474134      1        4       5     60
# D               Luke Schenn    8474568      1        4       5     62
# C             Micheal Haley    8474230      2        2       4     33
# D         Jonathan Ericsson    8470318      0        2       2     48
#
#           timeOnIcePerGame
# position
# C                    20.78
# C                    21.35
# ...

# %%
df.loc['D']
# Out:
#                        name  player_id  goals  assists  points  shots  \
# position
# D              John Carlson    8474590      9       38      47    132
# D                Roman Josi    8474600      9       30      39    180
# D                Torey Krug    8476792      6       32      38    118
# D               Brent Burns    8470613      8       29      37    163
# D             Victor Hedman    8475167      7       30      37    122
# ...                     ...        ...    ...      ...     ...    ...
# D             Brendan Smith    8474090      1        5       6     44
# D                Matt Irwin    8475625      0        6       6     77
# D             Yannick Weber    8474134      1        4       5     60
# D               Luke Schenn    8474568      1        4       5     62
# D         Jonathan Ericsson    8470318      0        2       2     48
#
#           timeOnIcePerGame
# position
# D                    23.21
# D                    24.14
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#     position               name  player_id  goals  assists  points  shots  \
# 0          C     Connor McDavid    8478402     26       48      74    173
# 1          C     Leon Draisaitl    8477934     29       43      72    160
# 2         RW    Nikita Kucherov    8476453     24       41      65    158
# 3          C   Nathan MacKinnon    8477492     25       39      64    233
# 4         LW     Artemi Panarin    8478550     21       42      63    150
# ..       ...                ...        ...    ...      ...     ...    ...
# 505        D         Matt Irwin    8475625      0        6       6     77
# 506        D      Yannick Weber    8474134      1        4       5     60
# 507        D        Luke Schenn    8474568      1        4       5     62
# 508        C      Micheal Haley    8474230      2        2       4     33
# 509        D  Jonathan Ericsson    8470318      0        2       2     48
#
#      timeOnIcePerGame
# 0               20.78
# 1               21.35
# ...
